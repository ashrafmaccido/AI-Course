# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdullah-Sada/AI-Assignment/blob/main/Chestnut_Manju.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Chestnut Problem

# %%
import math
import matplotlib.pyplot as plt

#Constants for chestnut and solar system
Chestnut_Diameter_cm = 2.54
Chestnut_Radius_cm = Chestnut_Diameter_cm / 2
Chestnut_Volume_cm3 = (4/3) * math.pi * (Chestnut_Radius_cm ** 3)
Chestnut_Volume_m3 = Chestnut_Volume_cm3 * 1e-6 # Convert to cubic meters

#Assumptions for the solar system (approximated)
Solar_System_Radius_Meters = 4.545e9
Solar_System_Volume_m3 = (4/3) * math.pi * (Solar_System_Radius_Meters ** 3)

#Lists to store volumes and time
volumes = []
minutes = []

#Function to calculate how many times it will double to fill space
def calculate_doubling_times(initial_volume, target_volume):
  doubling_times = 0
  while initial_volume < target_volume:
      initial_volume *= 2
      volumes.append(initial_volume)
      doubling_times += 5 #Doubling every 5minutes
      minutes.append(doubling_times)
  return doubling_times

#Calculate the time to fill the solar system with chestnut buns
time_to_fill_solar_system = calculate_doubling_times(Chestnut_Volume_m3, Solar_System_Volume_m3)

#Print the result
print(f"It will take {time_to_fill_solar_system} minutes to cover the Solar System with chestnut buns.")

#Visualize how volummes increase over time
plt.figure(figsize=(12, 7))
plt.plot(minutes, volumes)
plt.xlabel("Time (minutes)")
plt.ylabel("Volume (cubic meters)")
plt.title("Chestnut Bun Volume Increase Over Time")
plt.grid(True)
plt.show()
# Out:
# It will take 580 minutes to cover the Solar System with chestnut buns.

# %% [markdown]
# Tokyo Dome Example

# %%
Ball_Radius_cm = 11 #Example: Radius of the ball in centimeters
Ball_Volume_cm3 = (4/3) * math.pi * (Ball_Radius_cm ** 3)
Ball_Volume_m3 = Ball_Volume_cm3 * 1e-6 #Convert to cubic meters

#Assumptions for the Tokyo Dome (approximated)
Tokyo_Dome_Volume_m3 = 1240000

#Calculate the time to fill the Tokyo Dome with balls
time_to_fill_Tokyo_Dome = calculate_doubling_times(Ball_Volume_m3, Tokyo_Dome_Volume_m3)

#Print the result
print(f"It will take {time_to_fill_Tokyo_Dome} minutes to cover the Tokyo Dome with balls.")
# Out:
# It will take 140 minutes to cover the Tokyo Dome with balls.
